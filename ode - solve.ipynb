# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
tf.enable_eager_execution()

# %%
from tfdiffeq import odeint

# %%
NUM_SAMPLES = 1000
device = 'cpu:0'

# %%
from tfdiffeq import plot_phase_portrait, plot_vector_field, plot_results

# %%
initial_states = tf.convert_to_tensor([0., 1.], dtype=tf.float64); initial_states
# Out:
# <tf.Tensor: id=150690, shape=(2,), dtype=float64, numpy=array([0., 1.])>

# %%
t = tf.linspace(0., 50., num=1000); t.shape
# Out:
# TensorShape([Dimension(1000)])

# %%
class Lambda(tf.keras.Model):
  
  def call(self, t, y):
    # y now reprents the a vector of [u, v]
    u, v = y[0], y[1]
    
    du_dt = v
    dv_dt = -u/(1+u)
    
    return tf.stack([du_dt, dv_dt])  # vector of shape [2]

# %%
# %%time

with tf.device(device):
  result = odeint(Lambda(), initial_states, t)

print("Completed integration ! Output Shape =", result.shape)
# Out:
# Completed integration ! Output Shape = (1000, 2)
# CPU times: user 6.25 s, sys: 0 ns, total: 6.25 s
# Wall time: 6.27 s

# %%
result
# Out:
# <tf.Tensor: id=819603, shape=(100, 2), dtype=float64, numpy=
# array([[ 0.        ,  1.        ],
#        [ 0.05048411,  0.99876624],
#        [ 0.10084658,  0.99522157],
#        [ 0.15097628,  0.98957998],
#        [ 0.20077212,  0.98203113],
#        [ 0.25014205,  0.97274367],
#        [ 0.29900227,  0.96186725],
#        [ 0.34727593,  0.94953541],
#        [ 0.39489251,  0.93586832],
#        [ 0.44178735,  0.92097362],
#        [ 0.48790103,  0.90494807],
#        [ 0.53317873,  0.88787889],
#        [ 0.57756971,  0.86984558],
#        [ 0.62102693,  0.8509205 ],
#        [ 0.66350723,  0.831169  ],
#        [ 0.70497041,  0.81065099],
#        [ 0.74537925,  0.78942096],
#        [ 0.78469898,  0.76752943],
#        [ 0.82289724,  0.74502312],
#        [ 0.85994406,  0.72194494],
#        [ 0.89581179,  0.69833417],
#        [ 0.93047441,  0.67422771],
#        [ 0.96390784,  0.64965935],
#        [ 0.99608955,  0.62466088],
#        [ 1.02699854,  0.59926219],
#        [ 1.05661506,  0.57349155],
#        [ 1.08492102,  0.54737521],
#        [ 1.11189973,  0.52093768],
#        [ 1.13753575,  0.49420199],
#        [ 1.16181445,  0.46719033],
#        [ 1.18472244,  0.43992346],
#        [ 1.20624733,  0.41242129],
#        [ 1.22637765,  0.38470293],
#        [ 1.2451029 ,  0.35678664],
#        [ 1.26241354,  0.32868987],
#        [ 1.27830097,  0.30042926],
#        [ 1.29275737,  0.27202093],
#        [ 1.30577562,  0.24348056],
#        [ 1.31734944,  0.21482326],
#        [ 1.32747329,  0.18606384],
#        [ 1.33614233,  0.1572168 ],
#        [ 1.34335252,  0.12829626],
#        [ 1.34910047,  0.09931632],
#        [ 1.35338362,  0.0702903 ],
#        [ 1.35619996,  0.04123204],
#        [ 1.35754818,  0.01215466],
#        [ 1.35742764, -0.01692823],
#        [ 1.35583839, -0.04600352],
#        [ 1.35278115, -0.07505763],
#        [ 1.34825736, -0.10407694],
#        [ 1.3422691 , -0.13304817],
#        [ 1.3348192 , -0.16195742],
#        [ 1.32591107, -0.19079098],
#        [ 1.31554895, -0.21953448],
#        [ 1.30373761, -0.24817373],
#        [ 1.29048284, -0.27669356],
#        [ 1.27579095, -0.30507891],
#        [ 1.2596693 , -0.33331373],
#        [ 1.24212573, -0.36138207],
#        [ 1.22316922, -0.38926688],
#        [ 1.20280932, -0.41695081],
#        [ 1.18105672, -0.44441549],
#        [ 1.15792277, -0.47164209],
#        [ 1.13342028, -0.49861015],
#        [ 1.10756268, -0.5252987 ],
#        [ 1.08036479, -0.55168529],
#        [ 1.05184252, -0.57774643],
#        [ 1.02201259, -0.60345756],
#        [ 0.99089365, -0.62879192],
#        [ 0.95850502, -0.65372185],
#        [ 0.92486825, -0.67821693],
#        [ 0.89000592, -0.70224493],
#        [ 0.85394289, -0.72577087],
#        [ 0.81670501, -0.74875793],
#        [ 0.77832077, -0.77116579],
#        [ 0.73882011, -0.7929514 ],
#        [ 0.69823577, -0.81406826],
#        [ 0.65660258, -0.83446529],
#        [ 0.61395897, -0.85408599],
#        [ 0.57034543, -0.87286927],
#        [ 0.52580609, -0.89074868],
#        [ 0.48038762, -0.90765189],
#        [ 0.43414167, -0.92349817],
#        [ 0.38712383, -0.93819879],
#        [ 0.33939515, -0.95165441],
#        [ 0.29102033, -0.96375556],
#        [ 0.24207093, -0.97438068],
#        [ 0.19262489, -0.98339369],
#        [ 0.14276806, -0.9906416 ],
#        [ 0.092593  , -0.99595245],
#        [ 0.04220253, -0.99913314],
#        [-0.00829032, -0.99996539],
#        [-0.05876013, -0.99820114],
#        [-0.10906998, -0.99355966],
#        [-0.15906617, -0.98572188],
#        [-0.20857815, -0.97432427],
#        [-0.25741612, -0.9589542 ],
#        [-0.30536725, -0.9391434 ],
#        [-0.35219519, -0.91436235],
#        [-0.39763367, -0.8840182 ]])>

# %%
lims = [-2, 2]
plot_phase_portrait(Lambda(), xlims=lims, ylims=lims, ip_rank=1) # the function accepts a vector as input, so input rank is 1 by default.
plot_vector_field(result)
plt.xlim(lims)
plt.ylim(lims)
# Out:
# (-2, 2)

# %%
plot_results(t, result)
